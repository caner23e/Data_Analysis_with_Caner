# %%
#draw a triangle 
star= "*"
i=1
while i<=10:
    print(i* star)
    i+= 1
while i>=0:
    print(i* star)
    i -= 1
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
string_name= "This is my first Jupyter Notebook"

for i in string_name:
    if i !=" ":
        print(i)
# Out:
# T
# h
# i
# s
# i
# s
# m
# y
# f
# i
# r
# s
# t
# J
# u
# p
# y
# t
# e
# r
# N
# o
# t
# e
# b
# o
# o
# k
